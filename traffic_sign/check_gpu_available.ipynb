# %%
import cv2
import numpy as np
from ultralytics import YOLO
from collections import defaultdict, deque
import torch

ESC = 27
print(f"CUDA available: {torch.cuda.is_available()}")
# !nvidia-smi
# Out:
# CUDA available: True
# Tue Jan 20 18:39:42 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 591.44                 Driver Version: 591.44         CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4070 Ti   WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   42C    P5            N/A  /  N/A  |    2276MiB /  12282MiB |     39%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2240    C+G   ...crosoft\OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A            5508    C+G   ...0.3650.139\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           12364    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           12960    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A           14972    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A           15104    C+G   ...ms\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A           16272    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           18496    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           18920    C+G   ...0.3650.139\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           19328    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           19564    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           20440    C+G   ...\cef.win64\steamwebhelper.exe      N/A      |
# |    0   N/A  N/A           20476    C+G   ...lientElectron\Riot Client.exe      N/A      |
# |    0   N/A  N/A           20676    C+G   ...cord\app-1.0.9220\Discord.exe      N/A      |
# |    0   N/A  N/A           21960    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A           22136    C+G   ...em_tray\lghub_system_tray.exe      N/A      |
# |    0   N/A  N/A           22464    C+G   ...cord\app-1.0.9220\Discord.exe      N/A      |
# |    0   N/A  N/A           23520    C+G   ...8wekyb3d8bbwe\M365Copilot.exe      N/A      |
# |    0   N/A  N/A           26004    C+G   ...0.3650.139\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           26192    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           27952    C+G   ...__kzh8wxbdkxb8p\DCv2\DCv2.exe      N/A      |
# |    0   N/A  N/A           28320    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A           28660    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           31528    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           31768    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A           32276    C+G   ...ogram Files\DeskIn\DeskIn.exe      N/A      |
# +-----------------------------------------------------------------------------------------+
